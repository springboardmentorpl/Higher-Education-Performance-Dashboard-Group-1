# %%
import pandas as pd

# %%
df = pd.read_csv("university_raw_data.csv")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell'

# %%
df = pd.read_csv("university_raw_data.csv")

# %%
df.head()
# Out:
#   RANK_2025 RANK_2024                                    University  \
# 0         1         1  Massachusetts Institute of Technology (MIT)
# 1         2         6                       Imperial College London
# 2         3         3                          University of Oxford
# 3         4         4                            Harvard University
# 4         5         2                       University of Cambridge
#
#          Location    Region SIZE FOCUS RES. STATUS  Academic_Reputation_Score  \
# 0   United States  Americas    M    CO   VH      B                      100.0
# 1  United Kingdom    Europe    L    FC   VH      A                       98.5
# 2  United Kingdom    Europe    L    FC   VH      A                      100.0
# 3   United States  Americas    L    FC   VH      B                      100.0
# 4  United Kingdom    Europe    L    FC   VH      A                      100.0
#
#    ... Sustainability_Score  Sustainability_Rank Overall_Score  \
# ...

# %%
df.shape
# Out:
# (1503, 35)

# %%
df.shape
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 35 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   RANK_2025                             1503 non-null   str
#  1   RANK_2024                             1482 non-null   str
#  2   University                            1503 non-null   str
#  3   Location                              1503 non-null   str
#  4   Region                                1503 non-null   str
#  5   SIZE                                  1503 non-null   str
#  6   FOCUS                                 1503 non-null   str
#  7   RES.                                  1503 non-null   str
#  8   STATUS                                1466 non-null   str
#  9   Academic_Reputation_Score             1503 non-null   float64
#  10  Academic_Reputation_Rank              1503 non-null   str
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns = df.columns.str.strip()

# %%
df = df.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df["University"].head(20)
# Out:
# 0           Massachusetts Institute of Technology (MIT)
# 1                               Imperial College London
# 2                                  University of Oxford
# 3                                    Harvard University
# 4                               University of Cambridge
# 5                                   Stanford University
# 6     ETH Zurich - Swiss Federal Institute of Techno...
# 7                National University of Singapore (NUS)
# 8                                                   UCL
# 9          California Institute of Technology (Caltech)
# 10                           University of Pennsylvania
# 11             University of California, Berkeley (UCB)
# 12                          The University of Melbourne
# 13                                    Peking University
# 14    Nanyang Technological University, Singapore (NTU)
# 15                                   Cornell University
# 16                          The University of Hong Kong
# ...

# %%
df["University"].astype(str).str.contains(r"^\s|\s$", regex=True).sum()
# Out:
# np.int64(0)

# %%
df["University"] = df["University"].astype(str).str.strip()

# %%
df["University"].head(20)
# Out:
# 0           Massachusetts Institute of Technology (MIT)
# 1                               Imperial College London
# 2                                  University of Oxford
# 3                                    Harvard University
# 4                               University of Cambridge
# 5                                   Stanford University
# 6     ETH Zurich - Swiss Federal Institute of Techno...
# 7                National University of Singapore (NUS)
# 8                                                   UCL
# 9          California Institute of Technology (Caltech)
# 10                           University of Pennsylvania
# 11             University of California, Berkeley (UCB)
# 12                          The University of Melbourne
# 13                                    Peking University
# 14    Nanyang Technological University, Singapore (NTU)
# 15                                   Cornell University
# 16                          The University of Hong Kong
# ...

# %%
df["Location"].value_counts().head(20)
# Out:
# Location
# United States       197
# United Kingdom       90
# China (Mainland)     71
# Japan                49
# Germany              48
# Russia               47
# India                46
# South Korea          43
# Italy                42
# Australia            38
# France               35
# Brazil               35
# Spain                35
# Mexico               32
# Canada               30
# Malaysia             28
# Taiwan               27
# Indonesia            26
# Argentina            25
# Chile                25
# Name: count, dtype: int64

# %%
df["Location"].unique()[:20]
# Out:
# <StringArray>
# [   'United States',   'United Kingdom',      'Switzerland',
#         'Singapore',        'Australia', 'China (Mainland)',
#     'Hong Kong SAR',           'France',           'Canada',
#           'Germany',      'South Korea',            'Japan',
#       'Netherlands',         'Malaysia',          'Belgium',
#       'New Zealand',           'Taiwan',        'Argentina',
#            'Sweden',          'Ireland']
# Length: 20, dtype: str

# %%
df["Location"] = df["Location"].astype(str).str.strip()

# %%
df["Location"] = df["Location"].astype(str).str.strip()

# %%
df["Location"].astype(str).str.contains(r"^\s|\s$", regex=True).sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# RANK_2025                                 0
# RANK_2024                                21
# University                                0
# Location                                  0
# Region                                    0
# SIZE                                      0
# FOCUS                                     0
# RES.                                      0
# STATUS                                   37
# Academic_Reputation_Score                 0
# Academic_Reputation_Rank                  0
# Employer_Reputation_Score                 0
# Employer_Reputation_Rank                  0
# Faculty_Student_Score                     0
# Faculty_Student_Rank                      0
# Citations_per_Faculty_Score               0
# Citations_per_Faculty_Rank                0
# International_Faculty_Score             100
# International_Faculty_Rank              100
# International_Students_Score             58
# International_Students_Rank              58
# ...

# %%
missing_percentage = df.isnull().sum().sum() / df.size * 100
print(missing_percentage)
# Out:
# 13.825681969394543

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_percentage = missing_percentage[missing_percentage > 0].sort_values(ascending=False)

print(missing_percentage)
# Out:
# Overall_Score                           60.013307
# Rank                                    56.620093
# Research Quality                        56.620093
# Research Score                          56.620093
# International Outlook Score             56.620093
# Overall Score                           56.620093
# Overall Teaching Score                  56.620093
# Industry Income Score                   56.620093
# International_Faculty_Rank               6.653360
# International_Faculty_Score              6.653360
# International_Students_Rank              3.858949
# International_Students_Score             3.858949
# STATUS                                   2.461743
# RANK_2024                                1.397206
# Sustainability_Score                     1.264138
# Sustainability_Rank                      1.264138
# International_Research_Network_Score     0.066534
# International_Research_Network_Rank      0.066534
# dtype: float64

# %%
df.shape
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("university_cleaned.csv", index=False)

# %%
missing = df.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)

print(missing)
# Out:
# Overall_Score                           902
# Rank                                    851
# Research Quality                        851
# Research Score                          851
# International Outlook Score             851
# Overall Score                           851
# Overall Teaching Score                  851
# Industry Income Score                   851
# International_Faculty_Rank              100
# International_Faculty_Score             100
# International_Students_Rank              58
# International_Students_Score             58
# STATUS                                   37
# RANK_2024                                21
# Sustainability_Score                     19
# Sustainability_Rank                      19
# International_Research_Network_Score      1
# International_Research_Network_Rank       1
# dtype: int64

# %%
numeric_columns = df.select_dtypes(include="number").columns

for col in numeric_columns:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
missing_percentage = df.isnull().sum().sum() / df.size * 100
print(missing_percentage)
# Out:
# 0.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1503, 35)

# %%
df.to_csv("university_cleaned.csv", index=False)

# %%
print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
import os

print(os.path.exists("university_cleaned.csv"))
# Out:
# True

# %%
df.shape
# Out:
# (1503, 35)

# %%
df.head()
# Out:
#   RANK_2025 RANK_2024                                    University  \
# 0         1         1  Massachusetts Institute of Technology (MIT)
# 1         2         6                       Imperial College London
# 2         3         3                          University of Oxford
# 3         4         4                            Harvard University
# 4         5         2                       University of Cambridge
#
#          Location    Region SIZE FOCUS RES. STATUS  Academic_Reputation_Score  \
# 0   United States  Americas    M    CO   VH      B                      100.0
# 1  United Kingdom    Europe    L    FC   VH      A                       98.5
# 2  United Kingdom    Europe    L    FC   VH      A                      100.0
# 3   United States  Americas    L    FC   VH      B                      100.0
# 4  United Kingdom    Europe    L    FC   VH      A                      100.0
#
#    ... Sustainability_Score  Sustainability_Rank Overall_Score  \
# ...
